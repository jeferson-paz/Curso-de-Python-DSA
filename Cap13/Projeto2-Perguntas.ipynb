# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
#
# ## <font color='blue'>Fundamentos de Linguagem Python Para Análise de Dados e Data Science</font>
#
# ## <font color='blue'>Projeto 2</font>
#
# ## <font color='blue'>Análise Exploratória de Dados em Linguagem Python Para a Área de Varejo</font>

# %%
# ![DSA](imagens/projeto2.png) 
# Mudança realizada para importação da imagem direto do Github

# %%
from IPython.display import Image
Image(url="https://raw.githubusercontent.com/jeferson-paz/Curso-de-Python-DSA/main/Cap13/imagens/Projeto2.png")
# Out:
# <img src="https://raw.githubusercontent.com/jeferson-paz/Curso-de-Python-DSA/main/Cap13/imagens/Projeto2.png"/>

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.11.9

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# ## Carregando os Dados

# %%
# URL do arquivo CSV bruto no GitHub
url = 'https://raw.githubusercontent.com/jeferson-paz/Curso-de-Python-DSA/main/Cap13/dados/dataset.csv'

# %%
# Carrega o dataset
df = pd.read_csv(url)

# %%
# Exibir as primeiras linhas do DataFrame para verificar se foi carregado corretamente
print(df.head())
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
# Shape
df.shape
# Out:
# (9700, 11)

# %%
# Amostra dos dados
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
# Amostra dos dados
df.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 9695        Paper       22.830
# 9696   Appliances       54.320
# ...

# %% [markdown]
# ## Análise Exploratória

# %%
# Colunas do conjunto de dados
df.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
# Verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
# Resumo estatístico da coluna com o valor de venda
df['Valor_Venda'].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# Verificando se há registros duplicados
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
# Verificando de há valores ausentes
df.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %%
df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %% [markdown]
# ## Pergunta de Negócio 1:
#
# ### Qual Cidade com Maior Valor de Venda de Produtos da Categoria 'Office Supplies'?

# %%
# Filtrar os dados para a categoria 'Office Supplies'
df_office_supplies = df[df['Categoria'] == 'Office Supplies']

# Verificar se a coluna 'Cidade' existe no DataFrame
if 'Cidade' in df_office_supplies.columns:
    # Encontrar a linha com o maior valor de venda
    linha_maior_venda = df_office_supplies.loc[df_office_supplies['Valor_Venda'].idxmax()]

    # Extrair a cidade, o valor de venda e a categoria dessa linha
    cidade_maior_venda = linha_maior_venda['Cidade']
    valor_maior_venda = linha_maior_venda['Valor_Venda']
    categoria_maior_venda = linha_maior_venda['Categoria']

    # Mostrar estatísticas descritivas dos valores de venda
    descricao_valores_venda = df['Valor_Venda'].describe()

    # Exibir os resultados
    print(f"A cidade com o maior valor de venda de produtos da categoria '{categoria_maior_venda}' é: {cidade_maior_venda}")
    print(f"Valor de venda: {valor_maior_venda}")
    print(f"Categoria: {categoria_maior_venda}")
    print("\nEstatísticas descritivas dos valores de venda:")
    print(descricao_valores_venda)
else:
    print("A coluna 'Cidade' não existe no DataFrame.")
# Out:
# A cidade com o maior valor de venda de produtos da categoria 'Office Supplies' é: Detroit
# Valor de venda: 9892.74
# Categoria: Office Supplies
#
# Estatísticas descritivas dos valores de venda:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# ## Pergunta de Negócio 2:
#
# ### Qual o Total de Vendas Por Data do Pedido?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
# Converter a coluna 'Data_Pedido' para o formato de data
df['Data_Pedido'] = pd.to_datetime(df['Data_Pedido'], format='%d/%m/%Y')

# Calcular o total de vendas por data do pedido
vendas_por_data = df.groupby('Data_Pedido')['Valor_Venda'].sum().reset_index()

# Plotar o gráfico de barras
plt.figure(figsize=(12, 6))
plt.bar(vendas_por_data['Data_Pedido'], vendas_por_data['Valor_Venda'], color='skyblue')
plt.xlabel('Data do Pedido')
plt.ylabel('Total de Vendas')
plt.title('Total de Vendas Por Data do Pedido')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 3:
#
# ### Qual o Total de Vendas por Estado?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
# Calcular o total de vendas por estado
vendas_por_estado = df.groupby('Estado')['Valor_Venda'].sum().reset_index()

# Ordenar os dados pelo total de vendas (opcional)
vendas_por_estado = vendas_por_estado.sort_values(by='Valor_Venda', ascending=False)

# Plotar o gráfico de barras
plt.figure(figsize=(20, 8))
plt.bar(vendas_por_estado['Estado'], vendas_por_estado['Valor_Venda'], color='skyblue')
plt.xlabel('Estado')
plt.ylabel('Total de Vendas')
plt.title('Total de Vendas Por Estado')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 4:
#
# ### Quais São as 10 Cidades com Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
# Calcular o total de vendas por cidade
vendas_por_cidade = df.groupby('Cidade')['Valor_Venda'].sum().reset_index()

# Ordenar os dados pelo total de vendas em ordem decrescente e selecionar as 10 maiores
top_10_cidades = vendas_por_cidade.sort_values(by='Valor_Venda', ascending=False).head(10)

# Plotar o gráfico de barras
plt.figure(figsize=(12, 6))
plt.bar(top_10_cidades['Cidade'], top_10_cidades['Valor_Venda'], color='skyblue')
plt.xlabel('Cidade')
plt.ylabel('Total de Vendas')
plt.title('Top 10 Cidades com Maior Total de Vendas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 5:
#
# ### Qual Segmento Teve o Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de pizza.

# %%
# Calcular o total de vendas por segmento
vendas_por_segmento = df.groupby('Segmento')['Valor_Venda'].sum().reset_index()

# Plotar o gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(vendas_por_segmento['Valor_Venda'], labels=vendas_por_segmento['Segmento'], autopct='%1.1f%%', startangle=140)
plt.title('Total de Vendas por Segmento')
plt.axis('equal')  # Assegura que o gráfico de pizza seja desenhado como um círculo.
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 6 (Desafio Nível Baby):
#
# ### Qual o Total de Vendas Por Segmento e Por Ano?

# %%
# Converter a coluna 'Data_Pedido' para o formato de data
df['Data_Pedido'] = pd.to_datetime(df['Data_Pedido'], format='%d/%m/%Y')

# Extrair o ano da coluna 'Data_Pedido' e criar uma nova coluna 'Ano'
df['Ano'] = df['Data_Pedido'].dt.year

# Calcular o total de vendas por segmento e por ano
vendas_por_segmento_ano = df.groupby(['Ano', 'Segmento'])['Valor_Venda'].sum().unstack().fillna(0)

# Exibir o resultado
print(vendas_por_segmento_ano)
# Out:
# Segmento     Consumer    Corporate  Home Office
# Ano
# 2015      256719.9166  125819.5957   88229.0878
# 2016      265295.2593  114643.1229   74134.1332
# 2017      288459.5572  203266.7398  103639.6270
# 2018      323359.6019  235502.7284  156488.5849

# %% [markdown]
# ## Pergunta de Negócio 7 (Desafio Nível Júnior):
#
# Os gestores da empresa estão considerando conceder diferentes faixas de descontos e gostariam de fazer uma simulação com base na regra abaixo:
#
# - Se o Valor_Venda for maior que 1000 recebe 15% de desconto.
# - Se o Valor_Venda for menor que 1000 recebe 10% de desconto.
#
# ### Quantas Vendas Receberiam 15% de Desconto?

# %%
# Aplicar a regra de desconto
df['Desconto'] = df['Valor_Venda'].apply(lambda x: 0.15 if x > 1000 else 0.10)

# Contar o número de vendas que recebem 15% de desconto
vendas_15_desconto = df[df['Desconto'] == 0.15].shape[0]

# Exibir o resultado
print(f"Número de vendas que receberiam 15% de desconto: {vendas_15_desconto}")
# Out:
# Número de vendas que receberiam 15% de desconto: 457

# %% [markdown]
# ## Pergunta de Negócio 8 (Desafio Nível Master):
#
# ### Considere Que a Empresa Decida Conceder o Desconto de 15% do Item Anterior. Qual Seria a Média do Valor de Venda Antes e Depois do Desconto?

# %%
# Calcular a média do valor de venda antes do desconto
media_antes_desconto = df['Valor_Venda'].mean()

# Aplicar o desconto de 15% para valores maiores que 1000
df['Valor_Venda_Desconto'] = df['Valor_Venda'].apply(lambda x: x * 0.85 if x > 1000 else x)

# Calcular a média do valor de venda depois do desconto
media_depois_desconto = df['Valor_Venda_Desconto'].mean()

# Exibir os resultados
print(f"Média do valor de venda antes do desconto: {media_antes_desconto:.2f}")
print(f"Média do valor de venda depois do desconto: {media_depois_desconto:.2f}")
# Out:
# Média do valor de venda antes do desconto: 230.47
# Média do valor de venda depois do desconto: 215.51

# %% [markdown]
# ## Pergunta de Negócio 9 (Desafio Nível Master Ninja):
#
# ### Qual o Média de Vendas Por Segmento, Por Ano e Por Mês?
#
# Demonstre o resultado através de gráfico de linha.

# %% [markdown]
# ## Pergunta de Negócio 10 (Desafio Nível Master Ninja das Galáxias):
#
# ### Qual o Total de Vendas Por Categoria e SubCategoria, Considerando Somente as Top 12 SubCategorias?
#
# Demonstre tudo através de um único gráfico.

# %%
# Calcular o total de vendas por Categoria e SubCategoria
vendas_categoria_subcategoria = df.groupby(['Categoria', 'SubCategoria'])['Valor_Venda'].sum().reset_index()

# Obter as Top 12 SubCategorias com base no total de vendas
top_12_subcategorias = vendas_categoria_subcategoria.groupby('SubCategoria')['Valor_Venda'].sum().nlargest(12).index

# Filtrar o DataFrame para manter apenas as Top 12 SubCategorias
vendas_top_subcategorias = vendas_categoria_subcategoria[vendas_categoria_subcategoria['SubCategoria'].isin(top_12_subcategorias)]

# Criar o gráfico de barras
plt.figure(figsize=(14, 8))

# Agrupar os dados por Categoria e SubCategoria para plotar
for categoria in vendas_top_subcategorias['Categoria'].unique():
    dados_categoria = vendas_top_subcategorias[vendas_top_subcategorias['Categoria'] == categoria]
    plt.bar(dados_categoria['SubCategoria'], dados_categoria['Valor_Venda'], label=categoria, alpha=0.7)

# Adicionar título e rótulos aos eixos
plt.title('Total de Vendas Por Categoria e SubCategoria (Top 12 SubCategorias)')
plt.xlabel('SubCategoria')
plt.ylabel('Total de Vendas')

# Adicionar a legenda
plt.legend(title='Categoria')

# Adicionar grade e ajustar o layout
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Exibir o gráfico
plt.show()

# %% [markdown]
# # Fim
